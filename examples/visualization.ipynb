# %%
from google.colab import drive
drive.mount('/content/drive')

COMMONROAD_GEOMETRIC_PATH = "/content/drive/MyDrive/1 Universität/5. Semester/Autonomous Driving/code/"
REPO_PATH = "/content/drive/MyDrive/1 Universität/5. Semester/Autonomous Driving/code/project"

# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Setup

# %% [markdown]
# ## CommonRoad Geometric

# %%
import torch

# environment setup
def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# %cd {COMMONROAD_GEOMETRIC_PATH}

# install dependencies
# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric
# Out:
# /content/drive/MyDrive/1 Universität/5. Semester/Autonomous Driving/code
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cu111.html
# ...

# %%
# commonroad-io installation
# !pip install commonroad-io

# %%
# install commonroad geometric
# !pip install -e ./commonroad-geometric-io/
# Out:
# Obtaining file:///content/drive/MyDrive/1%20Universita%CC%88t/5.%20Semester/Autonomous%20Driving/code/commonroad-geometric-io
# ...
#   Attempting uninstall: commonroad-geometric-io
#     Found existing installation: commonroad-geometric-io 2021.0
#     Can't uninstall 'commonroad-geometric-io'. No files were found to uninstall.
#   Running setup.py develop for commonroad-geometric-io
# ...

# %% [markdown]
# ## Imports

# %%
# %cd {REPO_PATH}
# Out:
# /content/drive/MyDrive/1 Universität/5. Semester/Autonomous Driving/code/project

# %%
from visualization.visualization_data_retriever import VisualizationDataRetriever
from visualization.renderer import Renderer
from visualization.pca_visualization import PCAVisualization

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Render Scenarios

# %%
data = VisualizationDataRetriever(scenario_path = "test_data/DEU_LocationALower-11_1_T-1.xml", model_path = 'delete_me/min_dim_model/128.pth')

renderer = Renderer()
renderer.render(data.scenario, data.graphs, data.predictions, 10, 10, (300, 200))
renderer.save_movie(data.scenario, data.graphs, data.predictions, 13, "test.gif", (300, 200), 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/commonroad/geometry/shape.py:314: ShapelyDeprecationWarning: Setting custom attributes on geometry objects is deprecated, and will raise an AttributeError in Shapely 2.0
#   self.lanelet_id = lanelet_id
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-583834a103b9> in <module>()
# ----> 1 data = VisualizationDataRetriever(scenario_path = "test_data/DEU_LocationALower-11_1_T-1.xml", model_path = 'delete_me/min_dim_model/128.pth')
#
# /content/drive/MyDrive/1 Universität/5. Semester/Autonomous Driving/code/project/visualization/visualization_data_retriever.py in __init__(self, scenario_path, model_path)
#      10   def __init__(self, scenario_path: str, model_path: str):
#      11     self.scenario, _ = CommonRoadFileReader(filename=scenario_path).open()
# ---> 12     gnn = torch.load(model_path).cpu()
# ...

# %% [markdown]
# ## Display PCA results

# %%
pca_visualization = PCAVisualization("delete_me/model_state/pca2.m", "delete_me/model_state/heatmap_xyz2.pickle", data.graphs, data.hidden_representations)
print(pca_visualization.visualize(timestep=1, color="#64FF64"))
# Out:
# None

# %%
pca_visualization.visualize(timestep=70, ego_vehicle_id=9, color="#000000")
render(timestep=70, ego_vehicle=9, y=y, zoom=(250,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400 at 0x7FBF0AC8B3D0>

# %%
pca_visualization.visualize(timestep=100, ego_vehicle_id=15, color="#000000")
render(timestep=100, ego_vehicle=15, y=y, zoom=(250,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400 at 0x7FBF08DB09D0>

# %%
pca_visualization.visualize(timestep=20, ego_vehicle_id=18, color="#000000")
render(timestep=20, ego_vehicle=18, y=y, zoom=(250,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400 at 0x7FBF0B397890>

# %%
pca_visualization.visualize(timestep=102, ego_vehicle_id=8, color="#000000")
render(timestep=102, ego_vehicle=8, y=y, zoom=(250,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400 at 0x7FBF0876A0D0>
